# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import json
import requests

# %%
data=pd.read_csv('manga.csv')
data
# Out:
#                                             title_en  year
# 0                   Detective Conan: Zero’s Tea Time  2018
# 1                               The Nightmare Family  2020
# 2                                             Bassen  2017
# 3                                One Piece Episode A  2020
# 4  One Piece Special - Roronoa Zoro Falls Into th...  2019
# 5                                             Naruto  1999
# 6                              Tetsudou Shoujo Manga  2011
# 7   Detective Xeno and the Seven Locked Murder Rooms  2017
# 8                                         Slam Dunk!  1990
# 9                    A Goddess Without Inconvenience  2022

# %% [markdown]
# # API from MANGADEX

# %% [markdown]
# # URL

# %%
url_conan = "https://api.mangadex.org/manga?title=Detective Conan: Zero’s Tea Time"
url_nightmare = "https://api.mangadex.org/manga?title=The Nightmare Family"
url_bassen = "https://api.mangadex.org/manga?title=Bassen"
url_onepiece = "https://api.mangadex.org/manga?title=One Piece Episode A"
url_zoro = "https://api.mangadex.org/manga?title=One Piece Special - Roronoa Zoro Falls Into the Sea"
url_naruto = "https://api.mangadex.org/manga?title=Naruto"
url_tetsudou = "https://api.mangadex.org/manga?title=Tetsudou Shoujo Manga"
url_xeno = "https://api.mangadex.org/manga?title=Detective Xeno and the Seven Locked Murder Rooms"
url_slam = "https://api.mangadex.org/manga?title=Slam Dunk!"
url_goddess = "https://api.mangadex.org/manga?title=A Goddess Without Inconvenience"

# %% [markdown]
# # Detective Conan: Zero’s Tea Time
# ## Hit API

# %%
hit_conan = requests.request("GET", url_conan)
hit_conan.json()
pre_conan = hit_conan.json()
# pre_conan

# %%
norm_conan = pre_conan['data']
conan = pd.json_normalize(norm_conan)
conan
# Out:
#                                      id   type  \
# 0  09eb95d0-43ab-43d6-b045-96c1ea22d9ba  manga
#
#                                        relationships  \
# 0  [{'id': '9a561ea9-d3fc-484d-8585-4386fd66116d'...
#
#                 attributes.title.en  \
# 0  Detective Conan: Zero’s Tea Time
#
#                                 attributes.altTitles  \
# 0  [{'ja-ro': 'Zero no Nichijou'}, {'en': 'Zero's...
#
#                            attributes.description.en  attributes.isLocked  \
# 0  A Detective Conan spinoff featuring Amuro Toor...                False
#
#   attributes.links.al attributes.links.ap attributes.links.bw  ...  \
# 0              102750      zeros-tea-time       series/168726  ...
#
#   attributes.year attributes.contentRating  \
# 0            2018                     safe
#
#                                      attributes.tags attributes.state  \
# 0  [{'id': '391b0423-d847-456f-aff0-8b0cfc03066b'...        published
#
# ...

# %%
titles=conan.loc[:,['attributes.title.en']]
desc=conan.loc[:,['attributes.description.en']]
state=conan.loc[:,['attributes.state']]
language=conan.loc[:,['attributes.originalLanguage']]
publicdemographic=conan.loc[:,['attributes.publicationDemographic']]
lastChapter=conan.loc[:,['attributes.lastChapter']]
lastVolume=conan.loc[:,['attributes.lastVolume']]
status=conan.loc[:,['attributes.status']]
rating=conan.loc[:,['attributes.contentRating']]
version=conan.loc[:,['attributes.version']]

# %%
df_conan = pd.concat([titles,desc,state,language,publicdemographic,lastChapter,lastVolume,status,rating,version],axis=1, ignore_index=False)
df_conan
# Out:
#                 attributes.title.en  \
# 0  Detective Conan: Zero’s Tea Time
#
#                            attributes.description.en attributes.state  \
# 0  A Detective Conan spinoff featuring Amuro Toor...        published
#
#   attributes.originalLanguage attributes.publicationDemographic  \
# 0                          ja                           shounen
#
#   attributes.lastChapter attributes.lastVolume attributes.status  \
# 0                     60                     6         completed
#
#   attributes.contentRating  attributes.version
# 0                     safe                   6

# %%
df_conan = df_conan.rename(columns = {'attributes.title.en':'Title','attributes.description.en':'Description','attributes.state':'Statement','attributes.originalLanguage':'Original Language','attributes.publicationDemographic':'Publication Demographic',
                                     'attributes.lastChapter':'Last Chapter','attributes.lastVolume':'Last Volume','attributes.status':'Status','attributes.contentRating':'Rating','attributes.version':'Version'})
df_conan
# Out:
#                               Title  \
# 0  Detective Conan: Zero’s Tea Time
#
#                                          Description  Statement  \
# 0  A Detective Conan spinoff featuring Amuro Toor...  published
#
#   Original Language Publication Demographic Last Chapter Last Volume  \
# 0                ja                 shounen           60           6
#
#       Status Rating  Version
# 0  completed   safe        6

# %% [markdown]
# # The Nightmare Family
# ## Hit API

# %%
hit_nightmare = requests.request("GET", url_nightmare)
hit_nightmare.json()
pre_nightmare = hit_nightmare.json()
# pre_nightmare

# %%
norm_nightmare = pre_nightmare['data']
nightmare = pd.json_normalize(norm_nightmare)
nightmare
# Out:
#                                      id   type  \
# 0  1148e2b1-aaa7-4b4b-acfa-f62a7b3c5759  manga
#
#                                        relationships   attributes.title.en  \
# 0  [{'id': 'c8a34bf4-9e84-436e-8eec-5e2f6102a304'...  The Nightmare Family
#
#                                 attributes.altTitles  \
# 0  [{'ja': 'ナイトメア ファミリー'}, {'ja-ro': 'Naitomea Fa...
#
#                            attributes.description.en  attributes.isLocked  \
# 0  Poverty, domestic violence, abuse, abandonment...                False
#
#   attributes.links.mu attributes.originalLanguage attributes.lastVolume  ...  \
# 0              169748                          ja                     2  ...
#
#   attributes.year attributes.contentRating  \
# 0            2020                     safe
#
#                                      attributes.tags  attributes.state  \
# 0  [{'id': '4d32cc48-9f00-4cca-9b5a-a839f0764984'...         published
#
# ...

# %%
titles=nightmare.loc[:,['attributes.title.en']]
desc=nightmare.loc[:,['attributes.description.en']]
state=nightmare.loc[:,['attributes.state']]
language=nightmare.loc[:,['attributes.originalLanguage']]
publicdemographic=nightmare.loc[:,['attributes.publicationDemographic']]
lastChapter=nightmare.loc[:,['attributes.lastChapter']]
lastVolume=nightmare.loc[:,['attributes.lastVolume']]
status=nightmare.loc[:,['attributes.status']]
rating=nightmare.loc[:,['attributes.contentRating']]
version=nightmare.loc[:,['attributes.version']]

# %%
df_nightmare = pd.concat([titles,desc,state,language,publicdemographic,lastChapter,lastVolume,status,rating,version],axis=1, ignore_index=False)
df_nightmare
# Out:
#     attributes.title.en                          attributes.description.en  \
# 0  The Nightmare Family  Poverty, domestic violence, abuse, abandonment...
#
#   attributes.state attributes.originalLanguage  \
# 0        published                          ja
#
#   attributes.publicationDemographic attributes.lastChapter  \
# 0                            seinen
#
#   attributes.lastVolume attributes.status attributes.contentRating  \
# 0                     2         completed                     safe
#
#    attributes.version
# 0                   3

# %%
df_nightmare = df_nightmare.rename(columns = {'attributes.title.en':'Title','attributes.description.en':'Description','attributes.state':'Statement','attributes.originalLanguage':'Original Language','attributes.publicationDemographic':'Publication Demographic',
                                     'attributes.lastChapter':'Last Chapter','attributes.lastVolume':'Last Volume','attributes.status':'Status','attributes.contentRating':'Rating','attributes.version':'Version'})
df_nightmare
# Out:
#                   Title                                        Description  \
# 0  The Nightmare Family  Poverty, domestic violence, abuse, abandonment...
#
#    Statement Original Language Publication Demographic Last Chapter  \
# 0  published                ja                  seinen
#
#   Last Volume     Status Rating  Version
# 0           2  completed   safe        3

# %% [markdown]
# # Bassen
# ## Hit API

# %%
hit_bassen = requests.request("GET", url_bassen)
hit_bassen.json()
pre_bassen = hit_bassen.json()
# pre_bassen

# %%
norm_bassen = pre_bassen['data']
bassen = pd.json_normalize(norm_bassen)
bassen
# Out:
#                                      id   type  \
# 0  ad45fc82-85c2-409c-b781-6e863511af2c  manga
#
#                                        relationships attributes.title.en  \
# 0  [{'id': 'a7aa4bc7-6e39-4552-8ce8-6a3184c35004'...              Bassen
#
#                          attributes.altTitles attributes.description  \
# 0  [{'en': 'Batting Center'}, {'ja': 'ばっせん'}]                     []
#
#    attributes.isLocked                            attributes.links.raw  \
# 0                False  http://www.moae.jp/comic/shortandgagaudition/1
#
#   attributes.originalLanguage attributes.lastVolume  ... attributes.year  \
# 0                          ja                        ...            2017
#
#   attributes.contentRating                                    attributes.tags  \
# 0                     safe  [{'id': '0234a31e-a729-4e28-9d6a-3f87c4966b9e'...
#
#    attributes.state attributes.chapterNumbersResetOnNewVolume  \
# ...

# %%
titles=bassen.loc[:,['attributes.title.en']]
desc=bassen.loc[:,['attributes.description']]
state=bassen.loc[:,['attributes.state']]
language=bassen.loc[:,['attributes.originalLanguage']]
publicdemographic=bassen.loc[:,['attributes.publicationDemographic']]
lastChapter=bassen.loc[:,['attributes.lastChapter']]
lastVolume=bassen.loc[:,['attributes.lastVolume']]
status=bassen.loc[:,['attributes.status']]
rating=bassen.loc[:,['attributes.contentRating']]
version=bassen.loc[:,['attributes.version']]

# %%
df_bassen = pd.concat([titles,desc,state,language,publicdemographic,lastChapter,lastVolume,status,rating,version],axis=1, ignore_index=False)
df_bassen
# Out:
#   attributes.title.en attributes.description attributes.state  \
# 0              Bassen                     []        published
#
#   attributes.originalLanguage attributes.publicationDemographic  \
# 0                          ja                           shounen
#
#   attributes.lastChapter attributes.lastVolume attributes.status  \
# 0                                                      completed
#
#   attributes.contentRating  attributes.version
# 0                     safe                   4

# %%
df_bassen = df_bassen.rename(columns = {'attributes.title.en':'Title','attributes.description':'Description','attributes.state':'Statement','attributes.originalLanguage':'Original Language','attributes.publicationDemographic':'Publication Demographic',
                                     'attributes.lastChapter':'Last Chapter','attributes.lastVolume':'Last Volume','attributes.status':'Status','attributes.contentRating':'Rating','attributes.version':'Version'})
df_bassen
# Out:
#     Title Description  Statement Original Language Publication Demographic  \
# 0  Bassen          []  published                ja                 shounen
#
#   Last Chapter Last Volume     Status Rating  Version
# 0                           completed   safe        4

# %% [markdown]
# # One Piece Episode A
# ## Hit API

# %%
hit_onepiece = requests.request("GET", url_onepiece)
hit_onepiece.json()
pre_onepiece= hit_onepiece.json()
# pre_onepiece

# %%
norm_onepiece = pre_onepiece['data']
onepiece = pd.json_normalize(norm_onepiece)
onepiece
# Out:
#                                      id   type  \
# 0  f291e25f-aba8-459b-a929-67cc18a30be5  manga
# 1  189e5117-5e4d-403e-b315-3d500f44ee5d  manga
# 2  65f2e1a9-9a34-4123-a080-b3f34746e4a8  manga
# 3  470ac1ec-c3dd-4dc2-9e5d-0104600ed1a5  manga
# 4  0d1c6374-8d0c-4fde-8ae0-d13916b69f89  manga
# 5  a1c9cef0-540e-4f71-8891-ff7896cdde01  manga
# 6  7b5118a0-c0f3-409a-bca6-d5ef67e2ba2c  manga
# 7  6db2750d-dd46-4f1b-b607-8700a7536e1e  manga
# 8  1c4432d4-78ac-43c2-8c6a-9d77a95b19e3  manga
# 9  9b33e6ab-2970-426a-b749-e10d5271fe51  manga
#
#                                        relationships  \
# 0  [{'id': '66b880ff-f771-4188-aa72-f44683eeca5b'...
# 1  [{'id': 'bfcdf74c-5d2a-44ee-b176-567c20606d7e'...
# 2  [{'id': 'df486174-a87b-4936-8d07-2205d304c33a'...
# 3  [{'id': '687bd498-5e7d-48fb-80c9-33ab8c87ce90'...
# 4  [{'id': '2db64425-22c7-4fae-aebe-39863d94721e'...
# 5  [{'id': '7eccbb82-94a2-49ed-8b11-a52ca2574668'...
# 6  [{'id': 'b6045e2c-28f4-4ce0-b4dd-b14070f2f5ae'...
# ...

# %%
titles=onepiece.loc[:,['attributes.title.en']]
desc=onepiece.loc[:,['attributes.description']]
state=onepiece.loc[:,['attributes.state']]
language=onepiece.loc[:,['attributes.originalLanguage']]
publicdemographic=onepiece.loc[:,['attributes.publicationDemographic']]
lastChapter=onepiece.loc[:,['attributes.lastChapter']]
lastVolume=onepiece.loc[:,['attributes.lastVolume']]
status=onepiece.loc[:,['attributes.status']]
rating=onepiece.loc[:,['attributes.contentRating']]
version=onepiece.loc[:,['attributes.version']]

# %%
df_onepiece = pd.concat([titles,desc,state,language,publicdemographic,lastChapter,lastVolume,status,rating,version],axis=1, ignore_index=False)
df_onepiece
# Out:
#                                  attributes.title.en attributes.description  \
# 0       Kioku ga Ichinichi Shika Motanai Osananajimi                     []
# 1                        Full Marks, Hidden Marriage                    NaN
# 2  One Piece - Johnny & Yosaku Uncanon Adventures...                    NaN
# 3                                One Piece Episode A                    NaN
# 4  The Episode Where They Grope One Another’s Boo...                    NaN
# 5  One Punch Man - Saitama in the One Piece Unive...                     []
# 6                  One Piece: Special Episode "Luff"                    NaN
# 7    Seike Clone's Gate - One Piece Doujin Anthology                    NaN
# 8  The Young Lady and Her Lackeys Are Going to Pi...                    NaN
# 9           One Piece The Movie - Dead End no Bouken                    NaN
#
#   attributes.state attributes.originalLanguage  \
# 0        published                          ja
# ...

# %%
df_onepiece = df_onepiece.rename(columns = {'attributes.title.en':'Title','attributes.description':'Description','attributes.state':'Statement','attributes.originalLanguage':'Original Language','attributes.publicationDemographic':'Publication Demographic',
                                     'attributes.lastChapter':'Last Chapter','attributes.lastVolume':'Last Volume','attributes.status':'Status','attributes.contentRating':'Rating','attributes.version':'Version'})
df_onepiece
# Out:
#                                                Title Description  Statement  \
# 0       Kioku ga Ichinichi Shika Motanai Osananajimi          []  published
# 1                        Full Marks, Hidden Marriage         NaN  published
# 2  One Piece - Johnny & Yosaku Uncanon Adventures...         NaN  published
# 3                                One Piece Episode A         NaN  published
# 4  The Episode Where They Grope One Another’s Boo...         NaN  published
# 5  One Punch Man - Saitama in the One Piece Unive...          []  published
# 6                  One Piece: Special Episode "Luff"         NaN  published
# 7    Seike Clone's Gate - One Piece Doujin Anthology         NaN  published
# 8  The Young Lady and Her Lackeys Are Going to Pi...         NaN  published
# 9           One Piece The Movie - Dead End no Bouken         NaN  published
#
#   Original Language Publication Demographic Last Chapter Last Volume  \
# 0                ja                    None
# ...

# %% [markdown]
# # One Piece Special - Roronoa Zoro Falls Into the Sea
# ## Hit API

# %%
hit_zoro = requests.request("GET", url_zoro)
hit_zoro.json()
pre_zoro= hit_zoro.json()
# pre_zoro

# %%
norm_zoro = pre_zoro['data']
opzoro = pd.json_normalize(norm_zoro)
opzoro
# Out:
#                                      id   type  \
# 0  a1345e69-ac04-41d0-bf10-fceadc68d7e1  manga
#
#                                        relationships  \
# 0  [{'id': 'b6045e2c-28f4-4ce0-b4dd-b14070f2f5ae'...
#
#                                  attributes.title.en  \
# 0  One Piece Special - Roronoa Zoro Falls Into th...
#
#                                 attributes.altTitles  \
# 0  [{'en': 'One Piece Special - Boichi Crossover'...
#
#                            attributes.description.en  attributes.isLocked  \
# 0  Boichi's take on One Piece between chapters 51...                False
#
#   attributes.links.al                        attributes.links.ap  \
# 0              110450  one-piece-roronoa-zoro-falls-into-the-sea
#
#   attributes.links.kt  ... attributes.year attributes.contentRating  \
# 0               56883  ...            2019                     safe
#
#                                      attributes.tags attributes.state  \
# ...

# %%
titles=opzoro.loc[:,['attributes.title.en']]
desc=opzoro.loc[:,['attributes.description.en']]
state=opzoro.loc[:,['attributes.state']]
language=opzoro.loc[:,['attributes.originalLanguage']]
publicdemographic=opzoro.loc[:,['attributes.publicationDemographic']]
lastChapter=opzoro.loc[:,['attributes.lastChapter']]
lastVolume=opzoro.loc[:,['attributes.lastVolume']]
status=opzoro.loc[:,['attributes.status']]
rating=opzoro.loc[:,['attributes.contentRating']]
version=opzoro.loc[:,['attributes.version']]

# %%
df_opzoro = pd.concat([titles,desc,state,language,publicdemographic,lastChapter,lastVolume,status,rating,version],axis=1, ignore_index=False)
df_opzoro
# Out:
#                                  attributes.title.en  \
# 0  One Piece Special - Roronoa Zoro Falls Into th...
#
#                            attributes.description.en attributes.state  \
# 0  Boichi's take on One Piece between chapters 51...        published
#
#   attributes.originalLanguage attributes.publicationDemographic  \
# 0                          ja                           shounen
#
#   attributes.lastChapter attributes.lastVolume attributes.status  \
# 0                                                      completed
#
#   attributes.contentRating  attributes.version
# 0                     safe                   6

# %%
df_opzoro = df_opzoro.rename(columns = {'attributes.title.en':'Title','attributes.description.en':'Description','attributes.state':'Statement','attributes.originalLanguage':'Original Language','attributes.publicationDemographic':'Publication Demographic',
                                     'attributes.lastChapter':'Last Chapter','attributes.lastVolume':'Last Volume','attributes.status':'Status','attributes.contentRating':'Rating','attributes.version':'Version'})
df_opzoro
# Out:
#                                                Title  \
# 0  One Piece Special - Roronoa Zoro Falls Into th...
#
#                                          Description  Statement  \
# 0  Boichi's take on One Piece between chapters 51...  published
#
#   Original Language Publication Demographic Last Chapter Last Volume  \
# 0                ja                 shounen
#
#       Status Rating  Version
# 0  completed   safe        6

# %% [markdown]
# # Naruto
# ## Hit API

# %%
hit_naruto = requests.request("GET", url_naruto)
hit_naruto.json()
pre_naruto= hit_naruto.json()
# pre_naruto

# %%
norm_naruto = pre_naruto['data']
naruto = pd.json_normalize(norm_naruto)
naruto
# Out:
#                                      id   type  \
# 0  65125892-8584-4938-b45c-7a4cd9ad67d7  manga
# 1  46e530ce-0766-4cbd-b005-5e6fb0ba5e71  manga
# 2  6b1eb93e-473a-4ab3-9922-1a66d2a29a4a  manga
# 3  a787b10a-02d0-46c0-8236-0d01d69ad4a3  manga
# 4  e7e77e9b-cda8-4f4a-8ad6-ea0019d9a5af  manga
# 5  c75de038-fef5-4ea2-ae18-8aa5e01c5a7e  manga
# 6  cc33a2b4-02f0-48d8-97d7-7ba23a06d7e2  manga
# 7  c340a4a5-8c3c-497d-bde2-9010036d2e0a  manga
# 8  b31b5a81-3c8c-4c5f-8104-05299656c946  manga
# 9  54667339-618b-49bd-bad5-6910bf64861c  manga
#
#                                        relationships  \
# 0  [{'id': '1857aa7e-96d8-489f-9f37-9e5498cd6bec'...
# 1  [{'id': '54d2c255-f4a9-4bd5-b927-587ef9c4e3d2'...
# 2  [{'id': '7f718dfa-e5be-45ea-a5cb-0fcd3ed52d5f'...
# 3  [{'id': '7f718dfa-e5be-45ea-a5cb-0fcd3ed52d5f'...
# 4  [{'id': '32e375d6-2a59-4d3e-aed0-80a01b04191e'...
# 5  [{'id': 'cfff3b23-757f-4c01-978b-079ed31a226a'...
# 6  [{'id': '7f718dfa-e5be-45ea-a5cb-0fcd3ed52d5f'...
# ...

# %%
titles=naruto.loc[:,['attributes.title.en']]
desc=naruto.loc[:,['attributes.description.en']]
state=naruto.loc[:,['attributes.state']]
language=naruto.loc[:,['attributes.originalLanguage']]
publicdemographic=naruto.loc[:,['attributes.publicationDemographic']]
lastChapter=naruto.loc[:,['attributes.lastChapter']]
lastVolume=naruto.loc[:,['attributes.lastVolume']]
status=naruto.loc[:,['attributes.status']]
rating=naruto.loc[:,['attributes.contentRating']]
version=naruto.loc[:,['attributes.version']]

# %%
df_naruto = pd.concat([titles,desc,state,language,publicdemographic,lastChapter,lastVolume,status,rating,version],axis=1, ignore_index=False)
df_naruto
# Out:
#                                  attributes.title.en  \
# 0  Naruto: Sasuke's Story—The Uchiha and the Heav...
# 1                    Boruto: Naruto Next Generations
# 2                                             Naruto
# 3                    Naruto - Digital Colored Comics
# 4               Naruto dj - Kaleidoscope (Doujinshi)
# 5              Naruto dj - Feverish Cold (Doujinshi)
# 6  Naruto Gaiden: Nanadaime Hokage to Akairo no H...
# 7                    Naruto - Flower Art (Doujinshi)
# 8               Naruto - Summer Festival (Doujinshi)
# 9                              Dragon Ball Shippuden
#
#                            attributes.description.en attributes.state  \
# 0  Uchiha Sasuke heads for an astronomical observ...        published
# 1  Naruto was a young shinobi with an incorrigibl...        published
# 2  Before Naruto's birth, a great demon fox had a...        published
# 3  Twelve years ago, the powerful Nine-Tailed Dem...        published
# ...

# %%
df_naruto = df_naruto.rename(columns = {'attributes.title.en':'Title','attributes.description.en':'Description','attributes.state':'Statement','attributes.originalLanguage':'Original Language','attributes.publicationDemographic':'Publication Demographic',
                                     'attributes.lastChapter':'Last Chapter','attributes.lastVolume':'Last Volume','attributes.status':'Status','attributes.contentRating':'Rating','attributes.version':'Version'})
df_naruto
# Out:
#                                                Title  \
# 0  Naruto: Sasuke's Story—The Uchiha and the Heav...
# 1                    Boruto: Naruto Next Generations
# 2                                             Naruto
# 3                    Naruto - Digital Colored Comics
# 4               Naruto dj - Kaleidoscope (Doujinshi)
# 5              Naruto dj - Feverish Cold (Doujinshi)
# 6  Naruto Gaiden: Nanadaime Hokage to Akairo no H...
# 7                    Naruto - Flower Art (Doujinshi)
# 8               Naruto - Summer Festival (Doujinshi)
# 9                              Dragon Ball Shippuden
#
#                                          Description  Statement  \
# 0  Uchiha Sasuke heads for an astronomical observ...  published
# 1  Naruto was a young shinobi with an incorrigibl...  published
# 2  Before Naruto's birth, a great demon fox had a...  published
# 3  Twelve years ago, the powerful Nine-Tailed Dem...  published
# ...

# %% [markdown]
# # Tetsudou Shoujo Manga
# # Hit API

# %%
hit_tetsudou = requests.request("GET", url_tetsudou)
hit_tetsudou.json()
pre_tetsudou= hit_tetsudou.json()
# pre_tetsudou

# %%
norm_tetsudou = pre_tetsudou['data']
tetsudou = pd.json_normalize(norm_tetsudou)
tetsudou
# Out:
#                                      id   type  \
# 0  e50cb8c0-3368-4d74-a606-903588d0cdac  manga
#
#                                        relationships    attributes.title.en  \
# 0  [{'id': 'dc5c64ac-abc2-45e6-8d1a-83347fa2a7bc'...  Tetsudou Shoujo Manga
#
#                             attributes.altTitles  \
# 0  [{'en': 'Maiden Railways'}, {'en': '鉄道少女漫画'}]
#
#                            attributes.description.en  attributes.isLocked  \
# 0  A collection of discrete but interconnected lo...                False
#
#   attributes.links.al attributes.links.ap attributes.links.kt  ...  \
# 0               54301     maiden-railways               16564  ...
#
#   attributes.year attributes.contentRating  \
# 0            2011                     safe
#
#                                      attributes.tags attributes.state  \
# 0  [{'id': 'a3c67850-4684-404e-9b7f-c69850ee5da6'...        published
#
#   attributes.chapterNumbersResetOnNewVolume       attributes.createdAt  \
# ...

# %%
titles=tetsudou.loc[:,['attributes.title.en']]
desc=tetsudou.loc[:,['attributes.description.en']]
state=tetsudou.loc[:,['attributes.state']]
language=tetsudou.loc[:,['attributes.originalLanguage']]
publicdemographic=tetsudou.loc[:,['attributes.publicationDemographic']]
lastChapter=tetsudou.loc[:,['attributes.lastChapter']]
lastVolume=tetsudou.loc[:,['attributes.lastVolume']]
status=tetsudou.loc[:,['attributes.status']]
rating=tetsudou.loc[:,['attributes.contentRating']]
version=tetsudou.loc[:,['attributes.version']]

# %%
df_tetsudou = pd.concat([titles,desc,state,language,publicdemographic,lastChapter,lastVolume,status,rating,version],axis=1, ignore_index=False)
df_tetsudou
# Out:
#      attributes.title.en                          attributes.description.en  \
# 0  Tetsudou Shoujo Manga  A collection of discrete but interconnected lo...
#
#   attributes.state attributes.originalLanguage  \
# 0        published                          ja
#
#   attributes.publicationDemographic attributes.lastChapter  \
# 0                             josei                      7
#
#   attributes.lastVolume attributes.status attributes.contentRating  \
# 0                     1         completed                     safe
#
#    attributes.version
# 0                   4

# %%
df_tetsudou = df_tetsudou.rename(columns = {'attributes.title.en':'Title','attributes.description.en':'Description','attributes.state':'Statement','attributes.originalLanguage':'Original Language','attributes.publicationDemographic':'Publication Demographic',
                                     'attributes.lastChapter':'Last Chapter','attributes.lastVolume':'Last Volume','attributes.status':'Status','attributes.contentRating':'Rating','attributes.version':'Version'})
df_tetsudou
# Out:
#                    Title                                        Description  \
# 0  Tetsudou Shoujo Manga  A collection of discrete but interconnected lo...
#
#    Statement Original Language Publication Demographic Last Chapter  \
# 0  published                ja                   josei            7
#
#   Last Volume     Status Rating  Version
# 0           1  completed   safe        4

# %% [markdown]
# # Detective Xeno and the Seven Locked Murder Rooms
# ## Hit API

# %%
hit_xeno = requests.request("GET", url_xeno)
hit_xeno.json()
pre_xeno= hit_xeno.json()
# pre_xeno

# %%
norm_xeno = pre_xeno['data']
xeno = pd.json_normalize(norm_xeno)
xeno
# Out:
#                                      id   type  \
# 0  9aa3ca66-b1d0-4cc5-aec7-66990f026b78  manga
#
#                                        relationships  \
# 0  [{'id': 'e8ba237e-a819-4b99-b0e2-f8b16bc00d1b'...
#
#                                 attributes.title.en  \
# 0  Detective Xeno and the Seven Locked Murder Rooms
#
#                                 attributes.altTitles  \
# 0  [{'en': 'Detective Xeno and the Seven Locked M...
#
#                            attributes.description.en  \
# 0  The story follows Detective Xeno, who after be...
#
#                            attributes.description.pl  \
# 0  Na ulicy znaleziono nieprzytomnego, poranioneg...
#
#                            attributes.description.ru  attributes.isLocked  \
# 0  История о детективе Ксено, которого нашли в кр...                False
#
#   attributes.links.al  ... attributes.year attributes.contentRating  \
# 0              103060  ...            2017                     safe
#
# ...

# %%
titles=xeno.loc[:,['attributes.title.en']]
desc=xeno.loc[:,['attributes.description.en']]
state=xeno.loc[:,['attributes.state']]
language=xeno.loc[:,['attributes.originalLanguage']]
publicdemographic=xeno.loc[:,['attributes.publicationDemographic']]
lastChapter=xeno.loc[:,['attributes.lastChapter']]
lastVolume=xeno.loc[:,['attributes.lastVolume']]
status=xeno.loc[:,['attributes.status']]
rating=xeno.loc[:,['attributes.contentRating']]
version=xeno.loc[:,['attributes.version']]

# %%
df_xeno = pd.concat([titles,desc,state,language,publicdemographic,lastChapter,lastVolume,status,rating,version],axis=1, ignore_index=False)
df_xeno
# Out:
#                                 attributes.title.en  \
# 0  Detective Xeno and the Seven Locked Murder Rooms
#
#                            attributes.description.en attributes.state  \
# 0  The story follows Detective Xeno, who after be...        published
#
#   attributes.originalLanguage attributes.publicationDemographic  \
# 0                          ja                           shounen
#
#   attributes.lastChapter attributes.lastVolume attributes.status  \
# 0                     79                     8         completed
#
#   attributes.contentRating  attributes.version
# 0                     safe                   4

# %%
df_xeno = df_xeno.rename(columns = {'attributes.title.en':'Title','attributes.description.en':'Description','attributes.state':'Statement','attributes.originalLanguage':'Original Language','attributes.publicationDemographic':'Publication Demographic',
                                     'attributes.lastChapter':'Last Chapter','attributes.lastVolume':'Last Volume','attributes.status':'Status','attributes.contentRating':'Rating','attributes.version':'Version'})
df_xeno
# Out:
#                                               Title  \
# 0  Detective Xeno and the Seven Locked Murder Rooms
#
#                                          Description  Statement  \
# 0  The story follows Detective Xeno, who after be...  published
#
#   Original Language Publication Demographic Last Chapter Last Volume  \
# 0                ja                 shounen           79           8
#
#       Status Rating  Version
# 0  completed   safe        4

# %% [markdown]
# # Slam Dunk!
# ## Hit API

# %%
hit_slam = requests.request("GET", url_slam)
hit_slam.json()
pre_slam= hit_slam.json()
# pre_slam

# %%
norm_slam = pre_slam['data']
slam = pd.json_normalize(norm_slam)
slam
# Out:
#                                      id   type  \
# 0  319df2e2-e6a6-4e3a-a31c-68539c140a84  manga
# 1  2c7ef377-c77b-4824-86f9-ef2f7200c2de  manga
# 2  9ea603c8-f121-4fdf-a4af-ca3c106c0a59  manga
#
#                                        relationships  \
# 0  [{'id': '0b59098f-13c0-41cb-a110-9cbcec72dc0c'...
# 1  [{'id': '0b59098f-13c0-41cb-a110-9cbcec72dc0c'...
# 2  [{'id': 'f525561d-5bb4-45f7-9596-d677c62657e7'...
#
#                         attributes.title.en  \
# 0                                Slam Dunk!
# 1                   Slam Dunk (Fan Colored)
# 2  Slam Dunk - Fence of Defense (Doujinshi)
#
#                                 attributes.altTitles  \
# 0  [{'ja': 'スラム　ダンク'}, {'ja': 'スラムダンク'}, {'zh': '...
# 1  [{'en': 'Slam Dunk!'}, {'en': 'Slam Dunk'}, {'...
# 2                                                 []
#
#                            attributes.description.en  attributes.isLocked  \
# 0  Winning isn't everything in the game of basket...                False
# ...

# %%
titles=slam.loc[:,['attributes.title.en']]
desc=slam.loc[:,['attributes.description.en']]
state=slam.loc[:,['attributes.state']]
language=slam.loc[:,['attributes.originalLanguage']]
publicdemographic=slam.loc[:,['attributes.publicationDemographic']]
lastChapter=slam.loc[:,['attributes.lastChapter']]
lastVolume=slam.loc[:,['attributes.lastVolume']]
status=slam.loc[:,['attributes.status']]
rating=slam.loc[:,['attributes.contentRating']]
version=slam.loc[:,['attributes.version']]

# %%
df_slam = pd.concat([titles,desc,state,language,publicdemographic,lastChapter,lastVolume,status,rating,version],axis=1, ignore_index=False)
df_slam
# Out:
#                         attributes.title.en  \
# 0                                Slam Dunk!
# 1                   Slam Dunk (Fan Colored)
# 2  Slam Dunk - Fence of Defense (Doujinshi)
#
#                            attributes.description.en attributes.state  \
# 0  Winning isn't everything in the game of basket...        published
# 1  Winning isn't everything in the game of basket...        published
# 2                                                           published
#
#   attributes.originalLanguage attributes.publicationDemographic  \
# 0                          ja                           shounen
# 1                          ja                           shounen
# 2                          ja                              None
#
#   attributes.lastChapter attributes.lastVolume attributes.status  \
# 0                    276                    31         completed
# 1                    276                    31         completed
# ...

# %%
df_slam = df_slam.rename(columns = {'attributes.title.en':'Title','attributes.description.en':'Description','attributes.state':'Statement','attributes.originalLanguage':'Original Language','attributes.publicationDemographic':'Publication Demographic',
                                     'attributes.lastChapter':'Last Chapter','attributes.lastVolume':'Last Volume','attributes.status':'Status','attributes.contentRating':'Rating','attributes.version':'Version'})
df_slam
# Out:
#                                       Title  \
# 0                                Slam Dunk!
# 1                   Slam Dunk (Fan Colored)
# 2  Slam Dunk - Fence of Defense (Doujinshi)
#
#                                          Description  Statement  \
# 0  Winning isn't everything in the game of basket...  published
# 1  Winning isn't everything in the game of basket...  published
# 2                                                     published
#
#   Original Language Publication Demographic Last Chapter Last Volume  \
# 0                ja                 shounen          276          31
# 1                ja                 shounen          276          31
# 2                ja                    None         None        None
#
#       Status Rating  Version
# 0  completed   safe       22
# 1  completed   safe        3
# 2  completed   safe        2

# %% [markdown]
# # A Goddess Without Inconvenience
# ## Hit API

# %%
hit_goddess = requests.request("GET", url_goddess)
hit_goddess.json()
pre_goddess= hit_goddess.json()
# pre_goddess

# %%
norm_goddess = pre_goddess['data']
goddess = pd.json_normalize(norm_goddess)
goddess
# Out:
#                                      id   type  \
# 0  9b9a1913-cdab-4524-9339-434c876623a2  manga
# 1  9cc9cb81-0305-4a3c-9aeb-504b2635d2a4  manga
#
#                                        relationships  \
# 0  [{'id': '3d3dc3e4-97d5-4e07-9ebe-4490eabe1257'...
# 1  [{'id': '9a00b4f6-0941-44eb-8ae1-4f1d5b074858'...
#
#                                attributes.title.en  \
# 0                  A Goddess Without Inconvenience
# 1  The Struggle-Free Life of the Witch's Sacrifice
#
#                                 attributes.altTitles  \
# 0  [{'ja': '不都合のない女神さま'}, {'pt-br': 'Uma Deusa Se...
# 1  [{'en': 'Naivety in the Witch's Bountiful Care...
#
#                            attributes.description.en  \
# 0       A Goddess doing whatever you want her to do.
# 1  Near the western forest, there is a village th...
#
#                       attributes.description.pt-br  attributes.isLocked  \
# 0  Uma Deusa fazendo o que você quer que ela faça.                False
# ...

# %%
titles=goddess.loc[:,['attributes.title.en']]
desc=goddess.loc[:,['attributes.description.en']]
state=goddess.loc[:,['attributes.state']]
language=goddess.loc[:,['attributes.originalLanguage']]
publicdemographic=goddess.loc[:,['attributes.publicationDemographic']]
lastChapter=goddess.loc[:,['attributes.lastChapter']]
lastVolume=goddess.loc[:,['attributes.lastVolume']]
status=goddess.loc[:,['attributes.status']]
rating=goddess.loc[:,['attributes.contentRating']]
version=goddess.loc[:,['attributes.version']]

# %%
df_goddess = pd.concat([titles,desc,state,language,publicdemographic,lastChapter,lastVolume,status,rating,version],axis=1, ignore_index=False)
df_goddess
# Out:
#                                attributes.title.en  \
# 0                  A Goddess Without Inconvenience
# 1  The Struggle-Free Life of the Witch's Sacrifice
#
#                            attributes.description.en attributes.state  \
# 0       A Goddess doing whatever you want her to do.        published
# 1  Near the western forest, there is a village th...        published
#
#   attributes.originalLanguage attributes.publicationDemographic  \
# 0                          ja                              None
# 1                          ja                              None
#
#   attributes.lastChapter attributes.lastVolume attributes.status  \
# 0                                                      completed
# 1                                                        ongoing
#
#   attributes.contentRating  attributes.version
# 0                     safe                   5
# 1                     safe                   5

# %%
df_goddess = df_goddess.rename(columns = {'attributes.title.en':'Title','attributes.description.en':'Description','attributes.state':'Statement','attributes.originalLanguage':'Original Language','attributes.publicationDemographic':'Publication Demographic',
                                     'attributes.lastChapter':'Last Chapter','attributes.lastVolume':'Last Volume','attributes.status':'Status','attributes.contentRating':'Rating','attributes.version':'Version'})
df_goddess
# Out:
#                                              Title  \
# 0                  A Goddess Without Inconvenience
# 1  The Struggle-Free Life of the Witch's Sacrifice
#
#                                          Description  Statement  \
# 0       A Goddess doing whatever you want her to do.  published
# 1  Near the western forest, there is a village th...  published
#
#   Original Language Publication Demographic Last Chapter Last Volume  \
# 0                ja                    None
# 1                ja                    None
#
#       Status Rating  Version
# 0  completed   safe        5
# 1    ongoing   safe        5

# %%
# UNTUK MENGGABUNGKAN 2 KOLOM DARI BAWAH
df=pd.concat([df_conan,df_nightmare,df_bassen,df_onepiece,df_opzoro,df_naruto,df_tetsudou,df_xeno,df_slam,df_goddess], ignore_index=True)
df
# Out:
#                                                 Title  \
# 0                    Detective Conan: Zero’s Tea Time
# 1                                The Nightmare Family
# 2                                              Bassen
# 3        Kioku ga Ichinichi Shika Motanai Osananajimi
# 4                         Full Marks, Hidden Marriage
# 5   One Piece - Johnny & Yosaku Uncanon Adventures...
# 6                                 One Piece Episode A
# 7   The Episode Where They Grope One Another’s Boo...
# 8   One Punch Man - Saitama in the One Piece Unive...
# 9                   One Piece: Special Episode "Luff"
# 10    Seike Clone's Gate - One Piece Doujin Anthology
# 11  The Young Lady and Her Lackeys Are Going to Pi...
# 12           One Piece The Movie - Dead End no Bouken
# 13  One Piece Special - Roronoa Zoro Falls Into th...
# 14  Naruto: Sasuke's Story—The Uchiha and the Heav...
# 15                    Boruto: Naruto Next Generations
# ...

# %%
df_1=df.loc[df['Title'] == 'Detective Conan: Zero’s Tea Time']
df_2=df.loc[df['Title'] == 'The Nightmare Family']
df_3=df.loc[df['Title'] == 'Bassen']
df_4=df.loc[df['Title'] == 'One Piece Episode A']
df_5=df.loc[df['Title'] == 'One Piece Special - Roronoa Zoro Falls Into the Sea']
df_6=df.loc[df['Title'] == 'Naruto']
df_7=df.loc[df['Title'] == 'Tetsudou Shoujo Manga']
df_8=df.loc[df['Title'] == 'Detective Xeno and the Seven Locked Murder Rooms']
df_9=df.loc[df['Title'] == 'Slam Dunk!']
df_10=df.loc[df['Title'] == 'A Goddess Without Inconvenience']

# %%
# UNTUK MENGGABUNGKAN 2 KOLOM DARI BAWAH
df=pd.concat([df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9,df_10], ignore_index=True)
df
# Out:
#                                                Title  \
# 0                   Detective Conan: Zero’s Tea Time
# 1                               The Nightmare Family
# 2                                             Bassen
# 3                                One Piece Episode A
# 4  One Piece Special - Roronoa Zoro Falls Into th...
# 5                                             Naruto
# 6                              Tetsudou Shoujo Manga
# 7   Detective Xeno and the Seven Locked Murder Rooms
# 8                                         Slam Dunk!
# 9                    A Goddess Without Inconvenience
#
#                                          Description  Statement  \
# 0  A Detective Conan spinoff featuring Amuro Toor...  published
# 1  Poverty, domestic violence, abuse, abandonment...  published
# 2                                                 []  published
# 3                                                NaN  published
# ...

# %%
# UNTUK MENGGABUNGKAN 2 KOLOM DARI BAWAH
df_windy=pd.concat([data,df],axis=1)
df_windy
# Out:
#                                             title_en  year  \
# 0                   Detective Conan: Zero’s Tea Time  2018
# 1                               The Nightmare Family  2020
# 2                                             Bassen  2017
# 3                                One Piece Episode A  2020
# 4  One Piece Special - Roronoa Zoro Falls Into th...  2019
# 5                                             Naruto  1999
# 6                              Tetsudou Shoujo Manga  2011
# 7   Detective Xeno and the Seven Locked Murder Rooms  2017
# 8                                         Slam Dunk!  1990
# 9                    A Goddess Without Inconvenience  2022
#
#                                                Title  \
# 0                   Detective Conan: Zero’s Tea Time
# 1                               The Nightmare Family
# 2                                             Bassen
# 3                                One Piece Episode A
# ...

# %%
df_final_windy=df_windy.drop(['Title'],axis=1)
df_final_windy
# Out:
#                                             title_en  year  \
# 0                   Detective Conan: Zero’s Tea Time  2018
# 1                               The Nightmare Family  2020
# 2                                             Bassen  2017
# 3                                One Piece Episode A  2020
# 4  One Piece Special - Roronoa Zoro Falls Into th...  2019
# 5                                             Naruto  1999
# 6                              Tetsudou Shoujo Manga  2011
# 7   Detective Xeno and the Seven Locked Murder Rooms  2017
# 8                                         Slam Dunk!  1990
# 9                    A Goddess Without Inconvenience  2022
#
#                                          Description  Statement  \
# 0  A Detective Conan spinoff featuring Amuro Toor...  published
# 1  Poverty, domestic violence, abuse, abandonment...  published
# 2                                                 []  published
# ...

# %%
df_final_windy=df_final_windy.rename({'title_en':'Title','year':'Year'},axis=1)
df_final_windy
# Out:
#                                                Title  Year  \
# 0                   Detective Conan: Zero’s Tea Time  2018
# 1                               The Nightmare Family  2020
# 2                                             Bassen  2017
# 3                                One Piece Episode A  2020
# 4  One Piece Special - Roronoa Zoro Falls Into th...  2019
# 5                                             Naruto  1999
# 6                              Tetsudou Shoujo Manga  2011
# 7   Detective Xeno and the Seven Locked Murder Rooms  2017
# 8                                         Slam Dunk!  1990
# 9                    A Goddess Without Inconvenience  2022
#
#                                          Description  Statement  \
# 0  A Detective Conan spinoff featuring Amuro Toor...  published
# 1  Poverty, domestic violence, abuse, abandonment...  published
# 2                                                 []  published
# ...
